# %% [markdown]
# # Food recipes and herbal formulas: Figure 1 reproduction
#
# Run the cell below once. It displays the raw-data schema, preprocessing counts, duplicate handling, all plotted values, and the final figure.
#
# The five herbal CSV files are processed from their original rows. Recipe1M requires registration, so the public run shows its verified record schema and full-run metadata. Registered users can rerun the complete food preprocessing by following `DATA.md`.

# %%
# !git clone -q https://github.com/inseong101/HerbalFormulaCompletion.git
# %cd HerbalFormulaCompletion
# !pip install -q -r requirements.txt
# !python analysis.py
from IPython.display import Image, display
display(Image(filename='figures/Figure1_dataset_matching.png'))
